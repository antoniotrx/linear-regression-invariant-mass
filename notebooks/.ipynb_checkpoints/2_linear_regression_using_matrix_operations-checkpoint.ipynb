# %%
import pandas as pd
import numpy as np

# %%
data_filepath = "../data/cdata.csv"
data = pd.read_csv(data_filepath)

# %%
data.head()
# Out:
#       Run      Event        E1       px1        py1       pz1       pt1  \
# 0  147115  366639895  58.71410  -7.31132  10.531000 -57.29740  12.82020
# 1  147115  366704169   6.61188  -4.15213  -0.579855  -5.11278   4.19242
# 2  147115  367112316  25.54190 -11.48090   2.041680  22.72460  11.66100
# 3  147115  366952149  65.39590   7.51214  11.887100  63.86620  14.06190
# 4  147115  366523212  61.45040   2.95284 -14.622700 -59.61210  14.91790
#
#       eta1     phi1  Q1  ...      pz2       pt2      eta2      phi2  Q2  \
# 0 -2.20267  2.17766   1  ... -11.0778   2.14537 -2.344030 -2.072810  -1
# 1 -1.02842 -3.00284  -1  ...  11.4647  12.75360  0.808077  2.734920   1
# 2  1.42048  2.96560   1  ... -15.5888   2.69667 -2.455080  2.148570   1
# 3  2.21838  1.00721   1  ...  24.6563   4.84272  2.330210  0.565865  -1
# 4 -2.09375 -1.37154  -1  ... -13.6708   2.44145 -2.423700 -1.684810  -1
#
#           M       T_E       T_p1       T_p2        T_p
# ...

# %%
data.describe()
# Out:
#                  Run         Event            E1           px1           py1  \
# count   99892.000000  9.989200e+04  99892.000000  99892.000000  99892.000000
# mean   147935.537871  4.957532e+08     36.459695      0.136384      0.183445
# std       920.341884  4.038182e+08     41.223335     13.408913     13.475059
# min    146511.000000  6.414000e+03      0.377928   -250.587000   -126.079000
# 25%    147114.000000  2.023211e+08      8.471438     -5.236865     -5.282197
# 50%    147929.000000  3.902596e+08     21.740300      0.141563      0.100481
# 75%    149011.000000  6.340891e+08     50.063975      5.719105      5.652223
# max    149182.000000  1.791247e+09    850.602000    134.539000    147.467000
#
#                 pz1           pt1          eta1          phi1            Q1  \
# count  99892.000000  99892.000000  99892.000000  99892.000000  99892.000000
# mean      -1.512384     14.417882     -0.064220      0.021958     -0.005466
# ...

# %% [markdown]
# # Linear Regression Model using Matrix Operations

# %%
# split the predictors and the target variable in the data
y = data["M"]
x = data.drop(columns=["M", "Run", "Event"], axis=1)

# %%
# train-test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
x_train.shape
# Out:
# (69924, 20)

# %%
# Prepend 1 to each row of the predictors array
ones_column_train = np.ones((x_train.shape[0], 1))
ones_column_test = np.ones((x_test.shape[0], 1))
x_train = np.hstack([ones_column_train, x_train])
x_test = np.hstack([ones_column_test, x_test])

# %%
x_train.shape, x_test.shape
# Out:
# ((69924, 21), (29968, 21))

# %%
# Transpose x which is a 99892x21 matrix into a 21x99892 matrix
xTransposed = np.transpose(x_train)

# %%
# Calculate the beta column vector
beta = np.linalg.pinv(xTransposed.dot(x_train)).dot(xTransposed).dot(y_train)

# %%
beta
# Out:
# array([ 3.47881079e-01, -3.21495170e+02,  3.09786938e-03,  1.07342502e-02,
#         3.74533089e-03,  2.09004449e-01, -6.45120962e-03, -6.31688405e-02,
#         5.95928460e-03,  1.11104253e+02, -2.58386501e-04,  2.82537770e-03,
#        -1.65147081e-03,  9.30741080e-02,  1.58851616e-01, -3.43063384e-02,
#        -7.72150289e-03, -2.10273098e+02,  5.33208979e+02,  1.00651137e+02,
#        -1.31986578e+00])

# %%
# Calculate predictions for the target variable
yPredictions = x_test.dot(beta)

# %%
yPredictions[:5]
# Out:
# array([ 11.06076664,  23.98482976,   5.58506511, 114.28784963,
#          4.88629418])

# %%
# Real values of target variable
y_test[:5]
# Out:
# 72156    11.77330
# 42278    24.99360
# 14415     2.08228
# 66233    88.09680
# 8991      4.83112
# Name: M, dtype: float64

# %%
ae_series = np.abs(yPredictions - y_test)
se_series = np.square(yPredictions - y_test)
mae = ae_series.mean()
mse = se_series.mean()
rmse = np.sqrt(mse)

# %%
print(f"Mean squared error: {mse};\nRoot Mean Squared Error: {rmse};\nMean Absolute Error: {mae}.")
# Out:
# Mean squared error: 85.60264153028041;
# Root Mean Squared Error: 9.252169558016131;
# Mean Absolute Error: 6.303457291997952.
